# %% [markdown]
# <a href="https://colab.research.google.com/github/atc00009/DeepLearning-AthiraChitrapal/blob/main/Assignment_Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mping

# %%
from matplotlib import rcParams
plt.rcParams['figure.figsize'] =[12,8]
plt.rcParams['figure.dpi'] = 100

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('0002.png')
if(img is not None):
    cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)


img = cv2.fastNlMeansDenoisingColored(img, None, 10, 10, 7, 21)

cv2_imshow(img)

plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(img)
plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=481x321 at 0x7F596386CF50>

# %%
import cv2
from google.colab.patches import cv2_imshow
img1 = cv2.imread('0000.png')
img2 = cv2.imread('0001.png')
img3 = cv2.imread('0002.png')
img4 = cv2.imread('0003.png')
img5 = cv2.imread('0004.png')
img6 = cv2.imread('0005.png')
img7 = cv2.imread('0006.png')
img8 = cv2.imread('0007.png')
img9 = cv2.imread('0008.png')
img10 = cv2.imread('0009.png')
img11 = cv2.imread('0010.png')
img12 = cv2.imread('0011.png')
img13 = cv2.imread('0012.png')
img14 = cv2.imread('0013.png')
img15 = cv2.imread('0014.png')
img16 = cv2.imread('0015.png')
img17 = cv2.imread('0016.png')
img18 = cv2.imread('0017.png')
img19 = cv2.imread('0018.png')
img20 = cv2.imread('0019.png')
img21 = cv2.imread('0020.png')
img22 = cv2.imread('0021.png')
img23 = cv2.imread('0022.png')
img24 = cv2.imread('0023.png')




if(img1 is not None):
    cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
    print (img1)
if(img2 is not None):
    cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
if(img3 is not None):
    cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)
if(img4 is not None):
    cv2.cvtColor(img4, cv2.COLOR_BGR2GRAY)
  
if(img5 is not None):
    cv2.cvtColor(img5, cv2.COLOR_BGR2GRAY)
if(img6 is not None):
    cv2.cvtColor(img6, cv2.COLOR_BGR2GRAY)
if(img7 is not None):
    cv2.cvtColor(img7, cv2.COLOR_BGR2GRAY)
if(img8 is not None):
    cv2.cvtColor(img8, cv2.COLOR_BGR2GRAY)
  
if(img9 is not None):
    cv2.cvtColor(img9, cv2.COLOR_BGR2GRAY)
if(img10 is not None):
    cv2.cvtColor(img10, cv2.COLOR_BGR2GRAY)
if(img11 is not None):
    cv2.cvtColor(img11, cv2.COLOR_BGR2GRAY)
if(img12 is not None):
    cv2.cvtColor(img12, cv2.COLOR_BGR2GRAY)
if(img13 is not None):
    cv2.cvtColor(img13, cv2.COLOR_BGR2GRAY)
if(img14 is not None):
    cv2.cvtColor(img14, cv2.COLOR_BGR2GRAY)
if(img15 is not None):
    cv2.cvtColor(img15, cv2.COLOR_BGR2GRAY)
  
if(img16 is not None):
    cv2.cvtColor(img16, cv2.COLOR_BGR2GRAY)
  
if(img17 is not None):
    cv2.cvtColor(img17, cv2.COLOR_BGR2GRAY)
if(img18 is not None):
    cv2.cvtColor(img18, cv2.COLOR_BGR2GRAY)
if(img19 is not None):
    cv2.cvtColor(img19, cv2.COLOR_BGR2GRAY)
if(img20 is not None):
    cv2.cvtColor(img20, cv2.COLOR_BGR2GRAY)
  
if(img21 is not None):
    cv2.cvtColor(img21, cv2.COLOR_BGR2GRAY)



img1 = cv2.fastNlMeansDenoisingColored(img1, None, 10, 10, 7, 21)
img2 = cv2.fastNlMeansDenoisingColored(img2, None, 10, 10, 7, 21)
img3 = cv2.fastNlMeansDenoisingColored(img3, None, 10, 10, 7, 21)
img4 = cv2.fastNlMeansDenoisingColored(img4, None, 10, 10, 7, 21)
img5 = cv2.fastNlMeansDenoisingColored(img5, None, 10, 10, 7, 21)
img6 = cv2.fastNlMeansDenoisingColored(img6, None, 10, 10, 7, 21)
img7 = cv2.fastNlMeansDenoisingColored(img7, None, 10, 10, 7, 21)
img8 = cv2.fastNlMeansDenoisingColored(img8, None, 10, 10, 7, 21)
img9 = cv2.fastNlMeansDenoisingColored(img9, None, 10, 10, 7, 21)
img10 = cv2.fastNlMeansDenoisingColored(img10, None, 10, 10, 7, 21)
img11 = cv2.fastNlMeansDenoisingColored(img11, None, 10, 10, 7, 21)
img12 = cv2.fastNlMeansDenoisingColored(img12, None, 10, 10, 7, 21)
img13 = cv2.fastNlMeansDenoisingColored(img13, None, 10, 10, 7, 21)
img14 = cv2.fastNlMeansDenoisingColored(img14, None, 10, 10, 7, 21)
img15 = cv2.fastNlMeansDenoisingColored(img15, None, 10, 10, 7, 21)
img16 = cv2.fastNlMeansDenoisingColored(img16, None, 10, 10, 7, 21)
img17 = cv2.fastNlMeansDenoisingColored(img17, None, 10, 10, 7, 21)
img18 = cv2.fastNlMeansDenoisingColored(img18, None, 10, 10, 7, 21)
img19 = cv2.fastNlMeansDenoisingColored(img19, None, 10, 10, 7, 21)
img20 = cv2.fastNlMeansDenoisingColored(img20, None, 10, 10, 7, 21)
img21 = cv2.fastNlMeansDenoisingColored(img21, None, 10, 10, 7, 21)
img22 = cv2.fastNlMeansDenoisingColored(img22, None, 10, 10, 7, 21)
img23 = cv2.fastNlMeansDenoisingColored(img23, None, 10, 10, 7, 21)
img24 = cv2.fastNlMeansDenoisingColored(img24, None, 10, 10, 7, 21)


cv2_imshow(img1)

plt.subplot(121), plt.imshow(img1)
plt.subplot(122), plt.imshow(img1)
plt.show()

cv2_imshow(img2)

plt.subplot(221), plt.imshow(img2)
plt.subplot(222), plt.imshow(img2)
plt.show()

cv2_imshow(img2)

plt.subplot(321), plt.imshow(img)
plt.subplot(322), plt.imshow(img)
plt.show()
cv2_imshow(img)

plt.subplot(421), plt.imshow(img)
plt.subplot(422), plt.imshow(img)
plt.show()
cv2_imshow(img)

plt.subplot(521), plt.imshow(img)
plt.subplot(522), plt.imshow(img)
plt.show()
cv2_imshow(img)

plt.subplot(621), plt.imshow(img)
plt.subplot(622), plt.imshow(img)
plt.show()
cv2_imshow(img)
cv2_imshow(img)

plt.subplot(721), plt.imshow(img)
plt.subplot(722), plt.imshow(img)
plt.show()
cv2_imshow(img)

plt.subplot(821), plt.imshow(img)
plt.subplot(822), plt.imshow(img)
plt.show()


plt.subplot(921), plt.imshow(img)
plt.subplot(922), plt.imshow(img)
plt.show()
cv2_imshow(img)

plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(img)
plt.show()
cv2_imshow(img)

plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(img)
plt.show()
cv2_imshow(img)

plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(img)
plt.show()
cv2_imshow(img)

plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(img)
plt.show()
cv2_imshow(img)

plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(img)
plt.show()
cv2_imshow(img)

plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(img)
plt.show()
cv2_imshow(img)

plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(img)
plt.show()
cv2_imshow(img)

plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(img)
plt.show()
cv2_imshow(img)

plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(img)
plt.show()
cv2_imshow(img)

plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(img)
plt.show()
cv2_imshow(img)

plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(img)
plt.show()
cv2_imshow(img)

plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(img)
plt.show()
cv2_imshow(img)

plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(img)
plt.show()
cv2_imshow(img)

plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(img)
plt.show()
cv2_imshow(img)

plt.subplot(121), plt.imshow(img)
plt.subplot(122), plt.imshow(img)
plt.show()




cv2_imshow(img23)

plt.subplot(321), plt.imshow(img23)
plt.subplot(322), plt.imshow(img23)
plt.show()
# Out:
# [[[142 138 142]
#   [151 150 143]
#   [145 154 141]
#   ...
#   [142 120 139]
#   [132 132 141]
#   [122 116 112]]
#
#  [[139 112 126]
#   [154 122 126]
#   [129 128 127]
#   ...
#   [170 135 155]
#   [148 152 127]
#   [127 134 125]]
#
#  [[151 134 141]
#   [145 130 143]
#   [147 143 124]
#   ...
#   [147 141 147]
#   [151 125 125]
#   [168 120 133]]
#
#  ...
#
#  [[113  73  48]
#   [116  81  41]
#   [102  53  34]
#   ...
#   [120  88 109]
#   [121  97  75]
#   [115 116  98]]
#
#  [[ 62  63  11]
#   [100  57  38]
#   [109  79  50]
#   ...
#   [127  87  76]
#   [115  98 102]
#   [ 98  84  79]]
#
#  [[ 47   9   0]
#   [ 42   5   0]
#   [ 74  26  22]
#   ...
#   [111  92  86]
#   [103 100  93]
#   [ 83  66  70]]]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-89-bad42d00ae53> in <module>()
#      81
# ...
