# %% [markdown]
# <a href="https://colab.research.google.com/github/atc00009/DeepLearning-AthiraChitrapal/blob/main/Task_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing dataset library  to use CIFAR data
import keras                              
from keras.datasets import cifar10

# %%
# Importing other necessary libraries
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import seaborn as sns                    # to plot images and statical version of data
import numpy as np
import matplotlib.pyplot as plt
import random

from keras import layers

# %%
tf.__version__
# Out:
# '2.8.0'

# %%
keras.__version__
# Out:
# '2.8.0'

# %% [markdown]
# Load and Split Data

# %%
#Dataset of 50,000 32x32 color training images and 10,000 test images, labeled over 10 categories
#The data, split between train and test sets:
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
print('x_train shape:', x_train.shape)
print('y_train shape: ', y_train.shape)

print('\nx_test shape:', x_test.shape)
print('y_test shape: ', y_test.shape )

print('\nTotal train samples', x_train.shape[0])
print('Total test samples', x_test.shape[0])
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step
# 170508288/170498071 [==============================] - 2s 0us/step
# x_train shape: (50000, 32, 32, 3)
# y_train shape:  (50000, 1)
#
# x_test shape: (10000, 32, 32, 3)
# y_test shape:  (10000, 1)
#
# Total train samples 50000
# Total test samples 10000

# %% [markdown]
# Data Visulization

# %%
target = []
indexes=[]
while (len(target) != 10):
  j = random.randint(0, 49999)
  val = y_train[j][0]

  if val not in target:
    target.append(val)
    indexes.append(j)

# %%
# Display 10 random images from each class

# creating list of target values
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for  x in range(10):
    plt.subplot(5,5, x +1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[indexes[x]])                  # print the image
    plt.xlabel(class_names[y_train[indexes[x]][0]])  # The CIFAR labels happen to be arrays, which needs the extra index

plt.show()

# %% [markdown]
# Pre-Process data

# %%
# Normalize the data. Need to convert data type to float for computation.
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
num_classes=10
# Convert class vectors to binary class matrices, this is called one hot encoding.
y_train_ = tf.keras.utils.to_categorical(y_train, num_classes)
y_test_  = tf.keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# CNN Model - LeNet

# %%
from keras import datasets, layers, models
LeNet = models.Sequential()

LeNet.add(layers.Conv2D(6, (5,5), activation = 'tanh', strides  =1, input_shape= (32,32,3)))
LeNet.add(layers.AveragePooling2D())

LeNet.add(layers.Conv2D(16, (5,5), activation = 'tanh', strides= 1))
LeNet.add(layers.AveragePooling2D())

LeNet.add(layers.Flatten())

LeNet.add(layers.Dense(120, activation='tanh'))

LeNet.add(layers.Dense(84, activation='tanh'))

LeNet.add(layers.Dense(10, activation='softmax'))
LeNet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 6)         456
#
#  average_pooling2d (AverageP  (None, 14, 14, 6)        0
#  ooling2D)
#
#  conv2d_1 (Conv2D)           (None, 10, 10, 16)        2416
#
#  average_pooling2d_1 (Averag  (None, 5, 5, 16)         0
#  ePooling2D)
#
#  flatten (Flatten)           (None, 400)               0
#
#  dense (Dense)               (None, 120)               48120
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  dense_2 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 62,006
# Trainable params: 62,006
# Non-trainable params: 0
# _________________________________________________________________

# %%
LeNet.compile(optimizer = 'Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Training the model with 35 Epochs with coresponding train loss and accuracy
history_35 = LeNet.fit(x_train, y_train, epochs=35, verbose=1)
# Out:
# Epoch 1/35
# 1563/1563 [==============================] - 17s 5ms/step - loss: 1.7798 - accuracy: 0.3678
# Epoch 2/35
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.5301 - accuracy: 0.4558
# Epoch 3/35
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.4023 - accuracy: 0.4997
# Epoch 4/35
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.3255 - accuracy: 0.5290
# Epoch 5/35
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.2694 - accuracy: 0.5478
# Epoch 6/35
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.2176 - accuracy: 0.5667
# Epoch 7/35
# 1563/1563 [==============================] - 8s 5ms/step - loss: 1.1793 - accuracy: 0.5820
# Epoch 8/35
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.1415 - accuracy: 0.5945
# Epoch 9/35
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.1065 - accuracy: 0.6078
# Epoch 10/35
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.0767 - accuracy: 0.6185
# Epoch 11/35
# 1563/1563 [==============================] - 9s 5ms/step - loss: 1.0432 - accuracy: 0.6316
# Epoch 12/35
# 1563/1563 [==============================] - 9s 6ms/step - loss: 1.0165 - accuracy: 0.6416
# Epoch 13/35
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9883 - accuracy: 0.6517
# Epoch 14/35
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9651 - accuracy: 0.6580
# Epoch 15/35
# 1563/1563 [==============================] - 9s 5ms/step - loss: 0.9409 - accuracy: 0.6646
# Epoch 16/35
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.9166 - accuracy: 0.6743
# Epoch 17/35
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.8966 - accuracy: 0.6831
# Epoch 18/35
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8728 - accuracy: 0.6905
# Epoch 19/35
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.8522 - accuracy: 0.6989
# Epoch 20/35
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.8310 - accuracy: 0.7062
# Epoch 21/35
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.8110 - accuracy: 0.7134
# Epoch 22/35
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.7925 - accuracy: 0.7202
# Epoch 23/35
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7694 - accuracy: 0.7281
# Epoch 24/35
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7525 - accuracy: 0.7324
# Epoch 25/35
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.7352 - accuracy: 0.7394
# Epoch 26/35
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.7200 - accuracy: 0.7447
# Epoch 27/35
# 1563/1563 [==============================] - 9s 6ms/step - loss: 0.7050 - accuracy: 0.7514
# Epoch 28/35
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6859 - accuracy: 0.7550
# Epoch 29/35
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6751 - accuracy: 0.7596
# Epoch 30/35
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6581 - accuracy: 0.7660
# Epoch 31/35
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6439 - accuracy: 0.7709
# Epoch 32/35
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6320 - accuracy: 0.7766
# Epoch 33/35
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6128 - accuracy: 0.7825
# Epoch 34/35
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.6006 - accuracy: 0.7860
# Epoch 35/35
# 1563/1563 [==============================] - 8s 5ms/step - loss: 0.5911 - accuracy: 0.7894

# %%
history_35.history.keys()
# Out:
# dict_keys(['loss', 'accuracy'])

# %% [markdown]
#  Model Evaluation

# %%
accuracy_35 = history_35.history['accuracy']
loss_35 = history_35.history['loss']
epochs_35 = range(len(accuracy_35))

# %%
## Ploting Accuracy and loss after 35 epochs 
plt.plot(epochs_35, accuracy_35, 'b', label = 'Training Accuracy')
plt.plot(epochs_35, loss_35, 'g', label = 'Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy and Loss')
plt.title('Training Accuracy and Training Loss')
plt.legend()
plt.show()

# %%
# Evaluating model on train data
tr_score = LeNet.evaluate(x_train, y_train, verbose =0)
# Evaluating model on test data
score = LeNet.evaluate(x_test, y_test,verbose= 0)
# Model Training and Testing accuracy

print('Train accuracy: %.3f, Test accuracy: %.3f' % (tr_score[1], score[1]))
# Out:
# Train accuracy: 0.830, Test accuracy: 0.518

# %%
# Random image to test
test_i = random.randint(1, 10000)
plt.imshow(x_test[test_i]) # showing the image
class_names[y_test[test_i][0]] # showing the label of that images
# Out:
# 'frog'

# %%
import cv2
IMAGE_CHANNEL = 3

def prepare(filepath):
    IMG_SIZE = 32
    new_array = cv2.resize(x_test[test_i], (IMG_SIZE, IMG_SIZE))
    return new_array.reshape(-1, IMG_SIZE, IMG_SIZE, IMAGE_CHANNEL)

#Predicting the data on the model
predicted_class = LeNet.predict([prepare(x_test[test_i])])
class_names[np.argmax(predicted_class)]
# Out:
# 'frog'

# %% [markdown]
# Improving the Model

# %%
from keras import datasets, layers, models
LeNet_im = models.Sequential()

LeNet_im.add(layers.Conv2D(6, (7,7), activation = 'relu',padding = 'same', input_shape= (32,32,3)))   #padding set to same , filter size 7X7
LeNet_im.add(layers.MaxPooling2D())  # MaX pooling 

LeNet_im.add(layers.Conv2D(16, (7,7),padding = 'same',activation = 'relu'))  #padding set to same , filter size 7X7
LeNet_im.add(layers.BatchNormalization())  # batch normalization layer
LeNet_im.add(layers.MaxPooling2D())  # Maxpooling


# Added Convolutional and Maxpooling layer
LeNet_im.add(layers.Conv2D(32, (7,7),padding = 'same',activation = 'relu'))  #padding set to same , filter size 7X7
LeNet_im.add(layers.MaxPooling2D())  # Maxpooling

LeNet_im.add(layers.Flatten())

LeNet_im.add(layers.Dense(120, activation='relu'))

LeNet_im.add(layers.Dense(84, activation='relu'))
#added  a dense layer
LeNet_im.add(layers.Dense(43, activation='relu')) 
                          
LeNet_im.add(layers.Dense(10, activation='softmax'))
LeNet_im.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 32, 32, 6)         888
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 6)        0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 16, 16, 16)        4720
#
#  batch_normalization_1 (Batc  (None, 16, 16, 16)       64
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 8, 16)         0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 8, 8, 32)          25120
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 32)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 512)               0
#
#  dense_7 (Dense)             (None, 120)               61560
#
#  dense_8 (Dense)             (None, 84)                10164
#
#  dense_9 (Dense)             (None, 43)                3655
#
#  dense_10 (Dense)            (None, 10)                440
#
# =================================================================
# Total params: 106,611
# Trainable params: 106,579
# Non-trainable params: 32
# _________________________________________________________________

# %%
# optimizer as Stochastic Gradient Descent having learning rate and momentum set to 0.0001 and 0.9 respectively
opt = tf.keras.optimizers.SGD(learning_rate=0.0001,momentum= 0.9)      
LeNet_im.compile(optimizer = 'SGD', loss='sparse_categorical_crossentropy', metrics=['accuracy'])          # optimzer is Stochastic gradient descent

# %%
# Training the improved model
history_50 = LeNet_im.fit(x_train, y_train, epochs=50, batch_size=256, verbose=1)  #epochs as 50, batch_size=256
# Out:
# Epoch 1/50
# 196/196 [==============================] - 4s 18ms/step - loss: 2.0275 - accuracy: 0.2694
# Epoch 2/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.7141 - accuracy: 0.3774
# Epoch 3/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.5788 - accuracy: 0.4243
# Epoch 4/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.5025 - accuracy: 0.4545
# Epoch 5/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.4385 - accuracy: 0.4802
# Epoch 6/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.3957 - accuracy: 0.4970
# Epoch 7/50
# 196/196 [==============================] - 4s 19ms/step - loss: 1.3504 - accuracy: 0.5162
# Epoch 8/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.3172 - accuracy: 0.5275
# Epoch 9/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.2832 - accuracy: 0.5398
# Epoch 10/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.2449 - accuracy: 0.5551
# Epoch 11/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.2183 - accuracy: 0.5659
# Epoch 12/50
# 196/196 [==============================] - 3s 18ms/step - loss: 1.1954 - accuracy: 0.5742
# Epoch 13/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.1654 - accuracy: 0.5858
# Epoch 14/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.1440 - accuracy: 0.5919
# Epoch 15/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.1219 - accuracy: 0.6013
# Epoch 16/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0927 - accuracy: 0.6117
# Epoch 17/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0766 - accuracy: 0.6179
# Epoch 18/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0561 - accuracy: 0.6261
# Epoch 19/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0419 - accuracy: 0.6282
# Epoch 20/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0192 - accuracy: 0.6397
# Epoch 21/50
# 196/196 [==============================] - 4s 18ms/step - loss: 1.0038 - accuracy: 0.6444
# Epoch 22/50
# 196/196 [==============================] - 3s 18ms/step - loss: 0.9851 - accuracy: 0.6532
# Epoch 23/50
# 196/196 [==============================] - 3s 18ms/step - loss: 0.9691 - accuracy: 0.6556
# Epoch 24/50
# 196/196 [==============================] - 3s 18ms/step - loss: 0.9566 - accuracy: 0.6606
# Epoch 25/50
# 196/196 [==============================] - 3s 18ms/step - loss: 0.9389 - accuracy: 0.6678
# Epoch 26/50
# 196/196 [==============================] - 3s 18ms/step - loss: 0.9254 - accuracy: 0.6736
# Epoch 27/50
# 196/196 [==============================] - 3s 18ms/step - loss: 0.9180 - accuracy: 0.6754
# Epoch 28/50
# 196/196 [==============================] - 3s 18ms/step - loss: 0.9002 - accuracy: 0.6824
# Epoch 29/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.8909 - accuracy: 0.6861
# Epoch 30/50
# 196/196 [==============================] - 3s 18ms/step - loss: 0.8710 - accuracy: 0.6937
# Epoch 31/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.8628 - accuracy: 0.6972
# Epoch 32/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.8479 - accuracy: 0.7020
# Epoch 33/50
# 196/196 [==============================] - 3s 18ms/step - loss: 0.8370 - accuracy: 0.7052
# Epoch 34/50
# 196/196 [==============================] - 3s 18ms/step - loss: 0.8218 - accuracy: 0.7101
# Epoch 35/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.8120 - accuracy: 0.7136
# Epoch 36/50
# 196/196 [==============================] - 3s 18ms/step - loss: 0.8060 - accuracy: 0.7143
# Epoch 37/50
# 196/196 [==============================] - 3s 18ms/step - loss: 0.7933 - accuracy: 0.7202
# Epoch 38/50
# 196/196 [==============================] - 3s 18ms/step - loss: 0.7895 - accuracy: 0.7208
# Epoch 39/50
# 196/196 [==============================] - 3s 17ms/step - loss: 0.7721 - accuracy: 0.7289
# Epoch 40/50
# 196/196 [==============================] - 3s 18ms/step - loss: 0.7648 - accuracy: 0.7309
# Epoch 41/50
# 196/196 [==============================] - 3s 17ms/step - loss: 0.7537 - accuracy: 0.7359
# Epoch 42/50
# 196/196 [==============================] - 3s 18ms/step - loss: 0.7412 - accuracy: 0.7374
# Epoch 43/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.7330 - accuracy: 0.7409
# Epoch 44/50
# 196/196 [==============================] - 3s 17ms/step - loss: 0.7278 - accuracy: 0.7445
# Epoch 45/50
# 196/196 [==============================] - 3s 18ms/step - loss: 0.7183 - accuracy: 0.7484
# Epoch 46/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.7131 - accuracy: 0.7486
# Epoch 47/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.6890 - accuracy: 0.7591
# Epoch 48/50
# 196/196 [==============================] - 4s 18ms/step - loss: 0.6899 - accuracy: 0.7549
# Epoch 49/50
# 196/196 [==============================] - 3s 18ms/step - loss: 0.6837 - accuracy: 0.7583
# Epoch 50/50
# 196/196 [==============================] - 3s 18ms/step - loss: 0.6708 - accuracy: 0.7621

# %% [markdown]
# Improved Model Evaluation

# %%
accuracy_50 = history_50.history['accuracy']
loss_50 = history_50.history['loss']
epochs_50 = range(len(accuracy_50))

# %%
## Ploting Accuracy and loss after 35 epochs 
plt.plot(epochs_50, accuracy_50, 'b', label = 'Training Accuracy')
plt.plot(epochs_50, loss_50, 'g', label = 'Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Accuracy and Loss')
plt.title('Training Accuracy and Training Loss')
plt.legend()
plt.show()

# %%
# Evaluating model on train data
tr_score1 = LeNet_im.evaluate(x_train, y_train, verbose =0)
# Evaluating model on test data
score1 = LeNet_im.evaluate(x_test, y_test,verbose= 0)
# Model Training and Testing accuracy

print('Train accuracy: %.3f, Test accuracy: %.3f' % (tr_score1[1], score1[1]))
# Out:
# Train accuracy: 0.669, Test accuracy: 0.574

# %%
import cv2
IMAGE_CHANNEL = 3

def prepare(filepath):
    IMG_SIZE = 32
    new_array = cv2.resize(x_test[test_i], (IMG_SIZE, IMG_SIZE))
    return new_array.reshape(-1, IMG_SIZE, IMG_SIZE, IMAGE_CHANNEL)

#Predicting the data on the model
predicted_class = LeNet_im.predict([prepare(x_test[test_i])])
class_names[np.argmax(predicted_class)]
# Out:
# 'frog'
